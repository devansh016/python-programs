# %% [markdown]
# Write a Python program to get the difference between a given number and 17, if the number is greater than 17 return double the absolute difference.

# %%
n = int(input("Enter the number: "))
if n>17:
  print(2*(n-17))
else:
  print(17-n)
# Out:
# Enter the number: 18
# 2

# %% [markdown]
# Write a Python program to test whether a number is within 100 of 1000 or 2000.

# %%
n = int(input("Enter the number: "))
if abs(1000-n)<=100:
  print("Entered number is near 1000.")
elif abs(2000-n)<=100:
  print("Entered number is near 2000.")
else:
  print("Entered number is not near 1000 or 2000.")
# Out:
# Enter the number: 65546
# Entered number is not near 1000 or 2000.

# %% [markdown]
# Write a Python program to check whether a specified value is contained in a group of values.

# %%
def func(val, num):
  for i in val:
    if i == num:
      return True
  return False

print(func([1, 5, 8, 3], 3))
print(func([1, 5, 8, 3], -1))
# Out:
# True
# False

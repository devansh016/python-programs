# %% [markdown]
# WAP to add two matrices:
# Input:
# A = [[1,1], [1,1]]
# B = [[2,2], [2,2]]

# %%
A = [[1,1],[1,1]]
B = [[2,2],[2,2]]
C = [[0,0],[0,0]]

for i in range(len(A)):
   for j in range(len(A[0])):
       C[i][j] = A[i][j] + B[i][j]

for a in C:
   print(a)
# Out:
# [3, 3]
# [3, 3]

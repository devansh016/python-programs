# %% [markdown]
# Write a Python program to get an array buffer information Expected Output: Array buffer start address in memory and number of elements.

# %%
from array import *
a = array("i", (201, 461))
print("Array buffer start address in memory and number of elements.")
print(a.buffer_info())
# Out:
# Array buffer start address in memory and number of elements.
# (139709196697088, 2)

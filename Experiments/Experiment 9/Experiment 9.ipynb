# %% [markdown]
# Write a Python program to create an array of 5 integers and display the array items. Access individual element through indexes

# %%
from array import *
array_num = array('i', [8, 9, 2, 2 , 3])
print("First Element: ", array_num[0])
print("Second Element: ", array_num[1])
print("Third Element: ", array_num[2])
print("Forth Element: ", array_num[3])
print("Fifth Element: ", array_num[4])
# Out:
# First Element:  8
# Second Element:  9
# Third Element:  2
# Forth Element:  2
# Fifth Element:  3

# %% [markdown]
# Write a Python program to convert an array to an ordinary list with the same items.

# %%
from array import *
array_num = array('i', [3, 4, 2, 1, 9])
print("Original Array: ", (array_num))
num_list = array_num.tolist()
print("Ordinary list: ",num_list)
# Out:
# Original Array:  array('i', [3, 4, 2, 1, 9])
# Ordinary list:  [3, 4, 2, 1, 9]

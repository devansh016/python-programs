# %% [markdown]
# Q1. Write a program that accepts the lengths of three sides of a triangle as inputs.The program output should indicate whether or not the triangle is an equilateral triangle.

# %%
a = int(input('Enter side 1: '))
b = int(input('Enter side 2: '))
c = int(input('Enter side 3: '))
if a==b and b==c:
  print('Equilateral Triangle.')
else:
  print('Not an Equilateral Triangle.')
# Out:
# Enter side 1: 20
# Enter side 2: 30
# Enter side 3: 20
# Not an Equilateral Triangle.

# %% [markdown]
# Q2. Write a program that accepts the lengths of three sides of a triangle as inputs.The program output should indicate whether or not the triangle is a right triangle. Recall from the Pythagorean theorem that in a right triangle, the square ofone side equals the sum of the squares of the other two sides.

# %%
a = int(input('Enter side 1: '))
b = int(input('Enter side 2: '))
c = int(input('Enter side 3: '))

def check_triangle(x, y, z):
  if(x**2 == (y**2 + z**2)):
    print('\nRight Angled Triangle.')
  else:
    print('\nNot a Right Angled Triangle.')


if (a >= b) and (a >= c):
  check_triangle(a, b, c)
elif (b >= a) and (b >= c):
  check_triangle(b, a, c)
else:
  check_triangle(c, a, c)
# Out:
# Enter side 1: 10
# Enter side 2: 20
# Enter side 3: 30
#
# Not a Right Angled Triangle.

# %% [markdown]
# Q3. A standard science experiment is to drop a ball and see how high it bounces.Once the “bounciness” of the ball has been determined, the ratio gives a bouncinessindex. For example, if a ball dropped from a height of 10 feet bounces 6 feethigh, the index is 0.6, and the total distance travelled by the ball is 16 feet afterone bounce. If the ball were to continue bouncing, the distance after two bounceswould be 10 ft+ 6 ft+ 6 ft+ 3.6 ft = 25.6 ft. Note that the distance travelled foreach successive bounce is the distance to the floor plus 0.6 of that distance as theball comes back up. Write a program that lets the user enter the initial heightfrom which the ball is dropped and the number of times the ball is allowed tocontinue bouncing. Output should be the total distance travelled by the ball.

# %%
height = int(input('Enter initial height of ball: '))
no_of_bounces = int(input('Enter the number of time ball will bounce: '))

total_distance = 0

while(no_of_bounces!=0):
  total_distance += height + height*0.6
  height *=0.6
  no_of_bounces -=1

print(total_distance)
# Out:
# Enter initial height of ball: 10
# Enter the number of time ball will bounce: 1
# 16.0

# %% [markdown]
# Q4. A local biologist needs a program to predict population growth. The inputs would be the initial number of organisms, the rate of growth (a real number greater than 0), the number of hours it takes to achieve this rate, and a number of hours during which the population grows. For example, one might start with apopulation of 500 organisms, a growth rate of 2, and a growth period to achievethis rate of 6 hours. Assuming that none of the organisms die, this would implythat this population would double in size every 6 hours. Thus, after allowing 6 hours for growth, we would have 1000 organisms, and after 12 hours, we wouldhave 2000 organisms. Write a program that takes these inputs and displays a prediction of the total population.

# %%
organisms = int(input('Enter initial number of organisms: '))
rate = int(input('Enter rate of growth of organisms: '))
rate_time = int(input('Enter the number of hours it take to achieve this rate: '))
total_time = int(input('Enter the numbers of hours during which population grows: : '))

print('\nPredicted population: ',int(organisms * rate * total_time/rate_time));
# Out:
# Enter initial number of organisms: 500
# Enter rate of growth of organisms: 2
# Enter the number of hours it take to achieve this rate: 6
# Enter the numbers of hours during which population grows: : 12
#
# Predicted population:  2000
